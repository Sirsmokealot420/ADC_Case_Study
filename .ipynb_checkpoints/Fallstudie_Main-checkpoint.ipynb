# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('LGD_Panel.csv')
df.head()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
pd.set_option('display.max_columns', 20)

# %%
# Analysis of the dependent variable
sns.distplot(df['mat_time'])

plt.show()
